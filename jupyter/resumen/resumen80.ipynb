# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/pyCourse/blob/main/jupyter/resumen/resumen80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Funciones

# %% [markdown]
# ## Funciones internas de Python
# [Built-in functions](https://docs.python.org/3/library/functions.html)

# %% [markdown]
# ### `len`

# %%
semana = ['lun', 'mar', 'mie', 'jue', 'vie', 'sab', 'dom']
print(semana)
len(semana)

# %% [markdown]
# ### `max` y `min`

# %%
lista = [70, 75, 24, 67, 32]
print(f'Máximo: {max(lista)}')
print(f'Mínimo: {min(lista)}')

# %% [markdown]
# ### 'abs'

# %%
a, b = -3, 4
print(abs(a))
print(abs(b))

# %% [markdown]
# ### `sort`
# Es un **método** que ordena permanentemente una lista.

# %%
lista = [70, 75, 24, 67, 32]
lista.sort()
print(lista)

# %% [markdown]
# ### `sorted`
# Función que ordena una lista para imprimirla, pero la lista no queda ordenada.

# %%
lista = [70, 75, 24, 67, 32]
print(sorted(lista))
print(lista)

# %% [markdown]
# ### `type`

# %%
semana = ['lun', 'mar', 'mie', 'jue', 'vie', 'sab', 'dom']
type(semana)

# %%
capital = {"Italia":"Roma", "Francia":"París", "España":"Madrid"}
type(capital)

# %% [markdown]
# ### `round`

# %%
pi = 3.141592653589793
round(pi, 4)

# %% [markdown]
# ### `int`

# %%
int(42.95)

# %% [markdown]
# ### `str`

# %%
x = 15
print(x)
str(x)

# %% [markdown]
# ### `sum`

# %%
lista = list(range(11))
print(lista)
print(sum(lista))

# %% [markdown]
# ## Creación de funciones
# ```python
# def funcion(<parámetros>):
#     <código>
#     return <dato>
# ```

# %%
def sumar_numeros(a, b):   # a y b son los parámetros
    total = a + b
    return total

sumar_numeros(2, 3)   # invocación de la función. Los números 2 y 3 son los argumentos
