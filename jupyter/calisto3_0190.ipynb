# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/pyCourse/blob/main/jupyter/calisto3_0190.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tiempo de ejecución
# Tiempo de ejecución en segundos de un script.

# %%
import time
 
inicio = time.time()
 
# Código que deseamos medir, por ejemplo:
x = 0
for i in range(10_000_000):
    x += i
 
fin = time.time()
tiempo_total = fin - inicio
 
print(f'El tiempo de ejecución es {tiempo_total}')
# Out:
# El tiempo de ejecución es 1.3440275192260742
